# %% [markdown]
#  # Лабораторная работа: Собственная реализация алгоритма PCA
#
#
#
#  ## Цель работы
#
#  Изучить [метод главных компонент (PCA)](https://www.dmitrymakarov.ru/learning/pca/), реализовать алгоритм с нуля и сравнить с реализацией из библиотеки sklearn.
#
#
#
#
#  ## Задание
#
#
#
#  ### 1. Теоретическая часть
#
#
#
#  #### 1.1 Описание алгоритма PCA
#
#  **Задача:** Опишите назначение и основную идею алгоритма PCA. Объясните, для чего используется метод главных компонент.
#
#
#
#  #### 1.2 Математические основы
#
#  **Задача:** Распишите основные математические формулы для PCA:
#
#  - Формула для вычисления ковариационной матрицы
#
#  - Связь между собственными векторами и главными компонентами
#
#  - Формула преобразования данных в пространство главных компонент
#
#  - Формула для восстановления данных из сжатого представления

# %%
# Импорт необходимых библиотек
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris, make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd

# %% [markdown]
#  ### 2. Практическая часть
#
#
#
#  #### 2.1 Реализация PCA с нуля
#
#  **Задача:** Реализуйте класс MyPCA со следующими методами:
#
#  - `__init__(self, n_components)` - конструктор класса
#
#  - `fit(self, X)` - обучение модели (вычисление главных компонент)
#
#  - `transform(self, X)` - преобразование данных в пространство главных компонент
#
#  - `fit_transform(self, X)` - обучение и преобразование
#
#  - `inverse_transform(self, X_transformed)` - восстановление исходных данных
#
#
#
#  **Пошаговый алгоритм для реализации:**
#
#  1. Центрирование данных (вычесть среднее по каждому признаку)
#
#  2. Вычисление ковариационной матрицы
#
#  3. Поиск собственных значений и собственных векторов
#
#  4. Сортировка по убыванию собственных значений
#
#  5. Выбор первых n_components главных компонент
#
#  6. Преобразование данных

# %%
class MyPCA:
    def __init__(self, n_components):
        # TODO: инициализация параметров
        pass
    
    def fit(self, X):
        # TODO: реализовать обучение PCA
        # 1. Центрирование данных
        # 2. Вычисление ковариационной матрицы
        # 3. Поиск собственных значений и векторов
        # 4. Сортировка и выбор главных компонент
        pass
    
    def transform(self, X):
        # TODO: преобразование данных в пространство главных компонент
        pass
    
    def fit_transform(self, X):
        # TODO: обучение и преобразование
        pass
    
    def inverse_transform(self, X_transformed):
        # TODO: восстановление исходных данных
        pass

# %% [markdown]
#  #### 2.2 Тестирование на простых данных
#
#  **Задача:** Создайте простой 2D датасет и визуализируйте:
#
#  - Исходные данные
#
#  - Найденные главные компоненты (как векторы на графике)
#
#  - Данные после PCA преобразования

# %%
# TODO: создать простой 2D датасет для тестирования
# TODO: применить свою реализацию PCA
# TODO: визуализировать результаты

# %% [markdown]
#  #### 2.3 Работа с реальными данными
#
#  **Задача:** Используйте датасет Iris для сравнения вашей реализации с sklearn:
#
#
#
#  1. Загрузите и подготовьте данные
#
#  2. Примените стандартизацию
#
#  3. Выполните PCA с помощью вашей реализации
#
#  4. Выполните PCA с помощью sklearn
#
#  5. Сравните результаты

# %%
# TODO: загрузка и подготовка данных Iris
# TODO: стандартизация данных
# TODO: применение собственной реализации PCA
# TODO: применение sklearn PCA
# TODO: сравнение результатов

# %% [markdown]
#  #### 2.4 Анализ объясненной дисперсии
#
#  **Задача:**
#
#  1. Вычислите долю объясненной дисперсии для каждой главной компоненты
#
#  2. Постройте график зависимости накопленной объясненной дисперсии от количества компонент
#
#  3. Определите оптимальное количество компонент для сохранения 95% дисперсии

# %%
# TODO: вычисление объясненной дисперсии
# TODO: построение графика
# TODO: определение оптимального количества компонент

# %% [markdown]
#  #### 2.5 Визуализация результатов
#
#  **Задача:** Создайте визуализации:
#
#  1. 2D проекция исходных данных после PCA
#
#  2. Сравнение восстановленных данных с исходными
#
#  3. Heatmap ковариационной матрицы до и после PCA

# %%
# TODO: создание визуализаций

# %% [markdown]
#  ## Требования к отчету
#
#
#
#  1. **Теоретическая часть:** Полное описание алгоритма с математическими формулами
#
#  2. **Код:** Рабочая реализация всех методов с комментариями
#
#  3. **Результаты:** Графики, таблицы сравнения, анализ результатов
#
#  4. **Выводы:** Анализ преимуществ и недостатков различных реализаций
